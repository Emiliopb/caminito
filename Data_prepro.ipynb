# %% [markdown]
# # Data Pre procesing

# %% [markdown]
# ## Objetivos
#
# El objetivo de este Notebook sera preprocesar los distintos csv de las entradas del camino y generar un solo csv desde el que haremos el EDA

# %%
import pandas as pd
from pathlib import Path
import glob

# %%
entries_all = pd.DataFrame()

# %%
for excel_file in Path('./raw_csv_per_year').glob('*.xlsx'):
    conc = pd.read_excel(excel_file)
    
    entries_all = pd.concat([entries_all,conc])
    print(excel_file)
entries_all
# Out:
# raw_csv_per_year/2021.xlsx
# raw_csv_per_year/2017.xlsx
# raw_csv_per_year/2016.xlsx
# raw_csv_per_year/2020.xlsx
# raw_csv_per_year/2011.xlsx
# raw_csv_per_year/2010.xlsx
# raw_csv_per_year/2013.xlsx
# raw_csv_per_year/2012.xlsx
# raw_csv_per_year/2019.xlsx
# raw_csv_per_year/2015.xlsx
# raw_csv_per_year/2014.xlsx
# raw_csv_per_year/2022.xlsx
# raw_csv_per_year/2018.xlsx
#                  Entrada               Fecha Sexo  Edad       Continente  \
# 0        2021-01/0001-01 2021-01-01 10:24:45    M    38           Europa
# 1        2021-01/0001-02 2021-01-01 10:24:45    M    36           Europa
# 2        2021-01/0001-03 2021-01-01 10:24:45    M    40           Europa
# 3        2021-01/0001-04 2021-01-01 10:24:45    M    80           Europa
# 4        2021-01/0001-05 2021-01-01 10:24:45    M    36           Europa
# ...                  ...                 ...  ...   ...              ...
# 327362  2018-12/16494-16 2018-12-31 00:00:00    M    42  América del Sur
# 327363  2018-12/16494-17 2018-12-31 00:00:00    F    57           Europa
# 327364  2018-12/16494-18 2018-12-31 00:00:00    F    48           Europa
# 327365  2018-12/16494-19 2018-12-31 00:00:00    F    31           Europa
# 327366  2018-12/16494-20 2018-12-31 00:00:00    F    26           Europa
#
#              Pais      Autonomia Medio             Motivo  \
# 0        Portugal            NaN   Pie  Religioso y otros
# 1          España        Galicia   Pie  Religioso y otros
# 2         Rumania            NaN   Pie          Religioso
# 3          España  Castilla León   Pie          Religioso
# 4          España         Madrid   Pie  Religioso y otros
# ...           ...            ...   ...                ...
# 327362  Venezuela            NaN   Pie          Religioso
# 327363   Portugal            NaN   Pie          Religioso
# 327364   Portugal            NaN   Pie  Religioso y otros
# 327365    Ucrania            NaN   Pie          Religioso
# 327366    Ucrania            NaN   Pie  Religioso y otros
#
#                           Camino      Origen    Profesion
# 0       Costa Camino Portugues          Vigo      Parados
# 1              Frances-Camino de      Sarria    Liberales
# 2              Frances-Camino de      Sarria  Deportistas
# 3              Frances-Camino de      Sarria    Jubilados
# 4              Frances-Camino de  Vilafranca     Artistas
# ...                          ...         ...          ...
# 327362         Frances-Camino de      Sarria    Liberales
# 327363             Ingles-Camino    A Coruña   Profesores
# 327364             Ingles-Camino    A Coruña   Profesores
# 327365           Via de la Plata     Ourense    Liberales
# 327366        Invierno de Camino    Chantada  Estudiantes
#
# [3288651 rows x 12 columns]

# %%
entries_all.sort_values(by= 'Fecha', ascending=True)
# Out:
#                  Entrada               Fecha Sexo  Edad Continente      Pais  \
# 84       2010-01/0005-10 2010-01-01 00:00:00    M    41     Europa  Portugal
# 83       2010-01/0008-17 2010-01-01 00:00:00    M    53     Europa    España
# 82       2010-01/0008-16 2010-01-01 00:00:00    M    39     Europa    Italia
# 81       2010-01/0006-12 2010-01-01 00:00:00    M    22     Europa    España
# 80       2010-01/0001-15 2010-01-01 00:00:00    F    51     Europa    España
# ...                  ...                 ...  ...   ...        ...       ...
# 437905  2022-12/21756-10 2022-12-31 16:53:44    M    55     Europa  Alemania
# 437906  2022-12/21756-11 2022-12-31 17:38:37    M    47     Europa    España
# 437907  2022-12/21756-12 2022-12-31 17:50:16    M    55     Europa    España
# 437908  2022-12/21756-13 2022-12-31 17:50:37    F    53     Europa    España
# 437909  2022-12/21756-14 2022-12-31 17:53:58    F    43     Europa   Bélgica
#
#                     Autonomia Medio             Motivo              Camino  \
# 84                        NaN   Pie  Religioso y otros    Portugues-Camino
# 83                     Madrid   Pie          Religioso   Frances-Camino de
# 82                        NaN   Pie  Religioso y otros    Primitivo-Camino
# 81                     Madrid   Pie          Religioso     Via de la Plata
# 80                  Andalucía   Pie          Religioso   Frances-Camino de
# ...                       ...   ...                ...                 ...
# 437905  Residentes Extranjero   Pie  Religioso y otros  Invierno de Camino
# 437906            Extremadura   Pie  Religioso y otros       Ingles-Camino
# 437907               Cataluña   Pie          Religioso   Frances-Camino de
# 437908               Cataluña   Pie          Religioso   Frances-Camino de
# 437909  Residentes Extranjero   Pie  Religioso y otros   Frances-Camino de
#
#                     Origen    Profesion
# 84                     Tui   Profesores
# 83              Ponferrada    Liberales
# 82             Lugo - C.P.   Profesores
# 81                 Ourense  Estudiantes
# 80                  Sarria    Liberales
# ...                    ...          ...
# 437905  Ponferrada. C.Inv.          NaN
# 437906              Ferrol          NaN
# 437907     S. Jean P. Port          NaN
# 437908     S. Jean P. Port          NaN
# 437909             Bélgica          NaN
#
# [3288651 rows x 12 columns]

# %%
entries_all.sort_values(by= 'Entrada', ascending=True)
# Out:
#                  Entrada               Fecha Sexo  Edad Continente      Pais  \
# 0        2010-01/0001-01 2010-01-01 00:00:00    M    58     Europa    España
# 2        2010-01/0001-02 2010-01-01 00:00:00    M    62     Europa    España
# 7        2010-01/0001-03 2010-01-01 00:00:00    M    54     Europa    España
# 21       2010-01/0001-04 2010-01-01 00:00:00    F    44     Europa    España
# 22       2010-01/0001-05 2010-01-01 00:00:00    F    64     Europa  Alemania
# ...                  ...                 ...  ...   ...        ...       ...
# 437893  2022-12/21757-16 2022-12-31 16:45:23    M    56     Europa  Portugal
# 437894  2022-12/21757-17 2022-12-31 16:45:23    M    55     Europa  Portugal
# 437895  2022-12/21757-18 2022-12-31 16:45:23    M    28     Europa  Portugal
# 437896  2022-12/21757-19 2022-12-31 16:45:23    M    16     Europa  Portugal
# 437897  2022-12/21757-20 2022-12-31 16:45:24    M    52     Europa  Portugal
#
#                     Autonomia      Medio             Motivo  \
# 0                   Cantabria  Bicicleta          Religioso
# 2                    La Rioja        Pie          Religioso
# 7        Comunidad Valenciana        Pie          Religioso
# 21       Comunidad Valenciana        Pie          Religioso
# 22                        NaN        Pie          Religioso
# ...                       ...        ...                ...
# 437893  Residentes Extranjero  Bicicleta  Religioso y otros
# 437894  Residentes Extranjero  Bicicleta  Religioso y otros
# 437895  Residentes Extranjero  Bicicleta  Religioso y otros
# 437896  Residentes Extranjero  Bicicleta  Religioso y otros
# 437897  Residentes Extranjero  Bicicleta  Religioso y otros
#
#                    Camino           Origen  Profesion
# 0         Norte-Camino de  Resto Cantabria  Jubilados
# 2       Frances-Camino de           Sarria  Jubilados
# 7       Frances-Camino de       Ponferrada  Liberales
# 21      Frances-Camino de       Ponferrada   Tecnicos
# 22      Frances-Camino de          Astorga  Empleados
# ...                   ...              ...        ...
# 437893   Portugues-Camino           Lisboa        NaN
# 437894   Portugues-Camino           Lisboa        NaN
# 437895   Portugues-Camino           Lisboa        NaN
# 437896   Portugues-Camino           Lisboa        NaN
# 437897   Portugues-Camino           Lisboa        NaN
#
# [3288651 rows x 12 columns]

# %%
filepath = Path('Treated_csv/entries_all.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
entries_all.to_csv(filepath)
